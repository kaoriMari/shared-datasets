# %% [markdown]
# <a href="https://colab.research.google.com/github/kaoriMari/shared-datasets/blob/main/Supermarket_example_data_manip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Let's use the dataset [Supermarket-data](https://github.com/kaoriMari/shared-datasets/tree/main/supermarket-data)

# %% [markdown]
# ## Import the libraries: Pandas and Numpy

# %%
import pandas as pd
import numpy as np

# %%
datainput = pd.read_csv("https://raw.githubusercontent.com/kaoriMari/shared-datasets/main/supermarket-data/supermarket_sales.csv")

# %%
datainput2 = pd.read_csv('/content/supermarket_sales.csv')

# %%
datainput
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
datainput2
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# "Variable/object types":
# - integer
# - string
# - liste
# - series
# - dataframe (matrix)
#
# ...

# %%
testeserie = pd.Series([1,2,3,4,np.nan])

# %%
testeserie
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# dtype: float64

# %%
testedataframe = pd.DataFrame(testeserie)

# %%
testedataframe
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  3.0
# 3  4.0
# 4  NaN

# %% [markdown]
# ## Manipulation functions

# %%
datainput.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4

# %%
datainput.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
datainput.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
datainput.mean()
# Out:
# <ipython-input-14-fc6ae43435f5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datainput.mean()
# Unit price                  55.672130
# Quantity                     5.510000
# Tax 5%                      15.379369
# Total                      322.966749
# cogs                       307.587380
# gross margin percentage      4.761905
# gross income                15.379369
# Rating                       6.972700
# dtype: float64

# %%
datainput["Unit price"].mean()
# Out:
# 55.67213

# %%
datainput.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
datainput.shape
# Out:
# (1000, 17)

# %% [markdown]
# ## Classification

# %%
datainput.sort_values("Total")
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 822  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
# 629  308-39-1707      A     Yangon        Normal  Female  Fashion accessories
# 223  279-62-1445      C  Naypyitaw        Member  Female  Fashion accessories
# 443  192-98-7397      C  Naypyitaw        Normal    Male  Fashion accessories
# 402  236-86-3015      C  Naypyitaw        Member    Male   Home and lifestyle
# ..           ...    ...        ...           ...     ...                  ...
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
#
# ...

# %%
newtable = datainput.sort_values("Total")

# %%
newtable
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 822  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
# 629  308-39-1707      A     Yangon        Normal  Female  Fashion accessories
# 223  279-62-1445      C  Naypyitaw        Member  Female  Fashion accessories
# 443  192-98-7397      C  Naypyitaw        Normal    Male  Fashion accessories
# 402  236-86-3015      C  Naypyitaw        Member    Male   Home and lifestyle
# ..           ...    ...        ...           ...     ...                  ...
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
#
# ...

# %%
datainput.sort_values("Total", ascending=False)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 557  283-26-5248      C  Naypyitaw        Member  Female   Food and beverages
# 699  751-41-9720      C  Naypyitaw        Normal    Male   Home and lifestyle
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# ..           ...    ...        ...           ...     ...                  ...
# 402  236-86-3015      C  Naypyitaw        Member    Male   Home and lifestyle
# 443  192-98-7397      C  Naypyitaw        Normal    Male  Fashion accessories
# 223  279-62-1445      C  Naypyitaw        Member  Female  Fashion accessories
# 629  308-39-1707      A     Yangon        Normal  Female  Fashion accessories
# 822  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
#
# ...

# %%
datainput.sort_values("City")
# Out:
#       Invoice ID Branch      City Customer type  Gender         Product line  \
# 750  210-30-7976      B  Mandalay        Member  Female  Fashion accessories
# 570  834-83-1826      B  Mandalay        Member  Female   Home and lifestyle
# 285  498-41-1961      B  Mandalay        Normal    Male    Health and beauty
# 901  509-10-0516      B  Mandalay        Normal    Male   Home and lifestyle
# 571  343-61-3544      B  Mandalay        Member    Male    Sports and travel
# ..           ...    ...       ...           ...     ...                  ...
# 472  405-31-3305      A    Yangon        Member    Male  Fashion accessories
# 471  340-21-9136      A    Yangon        Member  Female    Sports and travel
# 464  470-32-9057      A    Yangon        Member    Male   Food and beverages
# 512  595-27-4851      A    Yangon        Normal  Female  Fashion accessories
# 999  849-09-3807      A    Yangon        Member  Female  Fashion accessories
#
# ...

# %% [markdown]
# ## Subset data

# %%
data2 = datainput['Product line']

# %%
data2
# Out:
# 0           Health and beauty
# 1      Electronic accessories
# 2          Home and lifestyle
# 3           Health and beauty
# 4           Sports and travel
#                 ...
# 995         Health and beauty
# 996        Home and lifestyle
# 997        Food and beverages
# 998        Home and lifestyle
# 999       Fashion accessories
# Name: Product line, Length: 1000, dtype: object

# %%
data2 = datainput[['Product line', 'Quantity']]

# %%
data2
# Out:
#                Product line  Quantity
# 0         Health and beauty         7
# 1    Electronic accessories         5
# 2        Home and lifestyle         7
# 3         Health and beauty         8
# 4         Sports and travel         7
# ..                      ...       ...
# 995       Health and beauty         1
# 996      Home and lifestyle        10
# 997      Food and beverages         1
# 998      Home and lifestyle         1
# 999     Fashion accessories         7
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Column creation

# %%
datainput["mariana"] = datainput['Total']/datainput['Quantity']

# %%
datainput
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
datainput['new col'] = datainput['Total']

# %%
datainput
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# # "Un peu de stat"

# %%
datainput.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
datainput.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating  ticket price  \
# count              1000.000000   1000.000000  1000.00000   1000.000000
# mean                  4.761905     15.379369     6.97270     58.455736
# std                   0.000000     11.708825     1.71858     27.819360
# ...

# %%
datainput['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
datainput['Product line'].value_counts(normalize=True)
# Out:
# Fashion accessories       0.178
# Food and beverages        0.174
# Electronic accessories    0.170
# Sports and travel         0.166
# Home and lifestyle        0.160
# Health and beauty         0.152
# Name: Product line, dtype: float64

# %% [markdown]
# ## Value Sum

# %%
total_vente = datainput['Total'].sum()

# %%
total_vente
# Out:
# 322966.749

# %%
# sommer le total par branch

branchA = datainput[datainput["Branch"]=="A"]['Total'].sum()
branchA
# Out:
# 106200.3705

# %%
#branch B

branchB = datainput[datainput["Branch"]=="B"]['Total'].sum()
branchB
# Out:
# 106197.67199999999

# %%
# branch C

branchC = datainput[datainput["Branch"]=="C"]['Total'].sum()
branchC
# Out:
# 110568.7065

# %%
branchAdata = datainput["Branch"]=="A"

# %%
branchAdata
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997     True
# 998     True
# 999     True
# Name: Branch, Length: 1000, dtype: bool

# %% [markdown]
# ## Delete value

# %%
dfexemple = [1,2,3,4,np.nan,6,7,np.nan]
dfexemple
# Out:
# [1, 2, 3, 4, nan, 6, 7, nan]

# %%
dfexemple1 = pd.DataFrame(dfexemple)
dfexemple1
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  3.0
# 3  4.0
# 4  NaN
# 5  6.0
# 6  7.0
# 7  NaN

# %%
dfexemple1.dropna()
# Out:
#      0
# 0  1.0
# 1  2.0
# 2  3.0
# 3  4.0
# 5  6.0
# 6  7.0

# %% [markdown]
# NaN = not a number

# %%
datainput
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
datainput.drop('new col', axis=1)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## Plot some graphs

# %% [markdown]
# Use matplotlib library to plot graphs

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(datainput['City'], datainput['Total'])
# Out:
# <BarContainer object of 1000 artists>

# %%
plt.bar(datainput['City'], datainput['Total'], color='red')
# Out:
# <BarContainer object of 1000 artists>
